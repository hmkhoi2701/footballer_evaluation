# %% [markdown]
# # Creating data table
# ## importing

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
PATH = Service("C:\Program Files (x86)\chromedriver.exe")

driver = webdriver.Chrome(service = PATH)
driver.close()

# %% [markdown]
# ## Reading local csv

# %%
club_read = pd.read_csv("raw_datasets\clubs.csv")
club_read.head()
# Out:
#    club_id                name         pretty_name domestic_competition_id  \
# 0     1032          fc-reading          Fc Reading                     GB1
# 1     2323            orduspor            Orduspor                     TR1
# 2     1387      acn-siena-1904      Acn Siena 1904                     IT1
# 3     3592  kryvbas-kryvyi-rig  Kryvbas Kryvyi Rig                    UKR1
# 4     1071      wigan-athletic      Wigan Athletic                     GB1
#
#    total_market_value  squad_size  average_age  foreigners_number  \
# 0               33.66          26         25.9                 12
# 1                 NaN           0          NaN                  0
# 2                4.32          30         26.2                  6
# 3                2.95          24         24.5                  2
# 4               12.38          29         26.5                 14
#
#    foreigners_percentage  national_team_players                stadium_name  \
# 0                   46.2                      6  Select Car Leasing Stadium
# 1                    NaN                      0            19 Eylül Stadyum
# 2                   20.0                      2             Artemio Franchi
# 3                    8.3                      0           Shakhty Zhovtneva
# 4                   48.3                      6                  DW Stadium
#
#    stadium_seats net_transfer_record        coach_name  \
# 0          24161             +£8.37m   Brian McDermott
# 1          11024                 +-0      Héctor Cúper
# 2          15373              £-6Th.       Serse Cosmi
# 3           2500            £-270Th.        Oleg Taran
# 4          25133            £-140Th.  Roberto Martínez
#
#                                                  url
# 0  https://www.transfermarkt.co.uk/fc-reading/sta...
# 1  https://www.transfermarkt.co.uk/orduspor/start...
# 2  https://www.transfermarkt.co.uk/acn-siena-1904...
# 3  https://www.transfermarkt.co.uk/kryvbas-kryvyi...
# 4  https://www.transfermarkt.co.uk/wigan-athletic...

# %%
competitions_read = pd.read_csv("raw_datasets\competitions.csv")
competitions_read.head()
# Out:
#   competition_id             name                type  country_id  \
# 0             L1       bundesliga          first_tier          40
# 1            DFB        dfb-pokal        domestic_cup          40
# 2            DFL     dfl-supercup  domestic_super_cup          40
# 3            NL1       eredivisie          first_tier         122
# 4            NLP  toto-knvb-beker        domestic_cup         122
#
#   country_name domestic_league_code confederation  \
# 0      Germany                   L1        europa
# 1      Germany                   L1        europa
# 2      Germany                   L1        europa
# 3  Netherlands                  NL1        europa
# 4  Netherlands                  NL1        europa
#
#                                                  url
# 0  https://www.transfermarkt.co.uk/bundesliga/sta...
# 1  https://www.transfermarkt.co.uk/dfb-pokal/star...
# 2  https://www.transfermarkt.co.uk/dfl-supercup/s...
# 3  https://www.transfermarkt.co.uk/eredivisie/sta...
# 4  https://www.transfermarkt.co.uk/toto-knvb-beke...

# %%
players_read = pd.read_csv("raw_datasets\players.csv")
players_read.head()
# Out:
#    player_id  last_season  current_club_id               name  \
# 0     254016         2013              855   arthur-delalande
# 1      51053         2013               23      daniel-davari
# 2      31451         2013               23      torsten-oehrl
# 3      44622         2013             3691  vladimir-kisenkov
# 4      30802         2013             3302         oscar-diaz
#
#          pretty_name country_of_birth country_of_citizenship date_of_birth  \
# 0   Arthur Delalande           France                 France     5/18/1992
# 1      Daniel Davari          Germany                   Iran      1/6/1988
# 2      Torsten Oehrl          Germany                Germany      1/7/1986
# 3  Vladimir Kisenkov            UdSSR                 Russia     10/8/1981
# 4         Oscar Diaz            Spain                  Spain     4/24/1984
#
#      position                 sub_position   foot  height_in_cm  \
# 0    Midfield  midfield - Central Midfield  Right           186
# 1  Goalkeeper                   Goalkeeper  Right           192
# 2      Attack      attack - Centre-Forward  Right           192
# 3    Defender        Defender - Right-Back  Right           182
# 4      Attack      attack - Centre-Forward  Right           183
#
#    market_value_in_gbp  highest_market_value_in_gbp  \
# 0                  NaN                      90000.0
# 1             135000.0                    1130000.0
# 2                  NaN                    1130000.0
# 3                  NaN                     720000.0
# 4                  NaN                    1080000.0
#
#                                                  url
# 0  https://www.transfermarkt.co.uk/arthur-delalan...
# 1  https://www.transfermarkt.co.uk/daniel-davari/...
# 2  https://www.transfermarkt.co.uk/torsten-oehrl/...
# 3  https://www.transfermarkt.co.uk/vladimir-kisen...
# 4  https://www.transfermarkt.co.uk/oscar-diaz/pro...

# %%
players_valuations_read = pd.read_csv("raw_datasets\player_valuations.csv")
players_valuations_read.head()
# Out:
#    player_id        date  market_value
# 0     254016  2013-07-22         90000
# 1     254016  2014-01-14         90000
# 2      51053  2008-08-25         90000
# 3      51053  2011-05-30         90000
# 4      51053  2011-08-26        225000

# %%
transfermarkt_url = [competitions_read.loc[competitions_read.domestic_league_code == x].iloc[0,7] 
       for x in ["GB1", "IT1", "ES1", "FR1", "L1"]]
transfermarkt_url
# Out:
# ['https://www.transfermarkt.co.uk/premier-league/startseite/wettbewerb/GB1',
#  'https://www.transfermarkt.co.uk/serie-a/startseite/wettbewerb/IT1',
#  'https://www.transfermarkt.co.uk/laliga/startseite/wettbewerb/ES1',
#  'https://www.transfermarkt.co.uk/ligue-1/startseite/wettbewerb/FR1',
#  'https://www.transfermarkt.co.uk/bundesliga/startseite/wettbewerb/L1']

# %%
PATH = Service("C:\Program Files (x86)\chromedriver.exe")

driver = webdriver.Chrome(service = PATH)

team_names = []

# extract only teams currently in the league
for league_url in transfermarkt_url:
    driver.get(league_url)

    
    # get number of teams in the league
    league_details = driver.find_element("xpath", "(//tbody)").find_element("xpath", "(//tr)[2]").get_attribute('innerHTML')
    league_details.replace(' ','')
    start_stamp = league_details.find('<td>')+5
    end_stamp = league_details.find('teams',start_stamp)
    no_of_teams = int(league_details[start_stamp:end_stamp].strip())

    
    # get name of each team, matching club table convention
    search = driver.find_element("xpath", "(//tbody)[4]")
    for _ in range (1, no_of_teams+1):
        detail = search.find_element("xpath","(//td[@class='hauptlink no-border-links'])[%i]" %_).get_attribute('innerHTML')
        start_stamp = detail.find('/')+1
        end_stamp = detail.find('/',start_stamp)
        team_names.append(detail[start_stamp:end_stamp])

driver.close()

team_names
# Out:
# ['manchester-city',
#  'fc-liverpool',
#  'fc-chelsea',
#  'manchester-united',
#  'tottenham-hotspur',
#  'fc-arsenal',
#  'leicester-city',
#  'aston-villa',
#  'fc-everton',
#  'wolverhampton-wanderers',
#  'west-ham-united',
#  'leeds-united',
#  'newcastle-united',
#  'brighton-amp-hove-albion',
#  'fc-southampton',
#  'fc-brentford',
#  'crystal-palace',
#  'norwich-city',
#  'fc-watford',
#  'fc-burnley',
#  'ac-mailand',
#  'juventus-turin',
#  'inter-mailand',
#  'ssc-neapel',
#  'as-rom',
#  'atalanta-bergamo',
#  'lazio-rom',
#  'us-sassuolo',
#  'ac-florenz',
#  'fc-turin',
#  'fc-bologna',
#  'hellas-verona',
#  'udinese-calcio',
#  'fc-empoli',
#  'cagliari-calcio',
#  'genua-cfc',
#  'sampdoria-genua',
#  'spezia-calcio',
#  'venezia-fc',
#  'us-salernitana-1919',
#  'real-madrid',
#  'fc-barcelona',
#  'atletico-madrid',
#  'fc-villarreal',
#  'real-sociedad-san-sebastian',
#  'fc-sevilla',
#  'fc-valencia',
#  'real-betis-sevilla',
#  'athletic-bilbao',
#  'fc-getafe',
#  'espanyol-barcelona',
#  'celta-vigo',
#  'ca-osasuna',
#  'fc-granada',
#  'ud-levante',
#  'fc-elche',
#  'rcd-mallorca',
#  'fc-cadiz',
#  'rayo-vallecano',
#  'deportivo-alaves',
#  'fc-paris-saint-germain',
#  'as-monaco',
#  'olympique-lyon',
#  'olympique-marseille',
#  'ogc-nizza',
#  'fc-stade-rennes',
#  'losc-lille',
#  'rc-lens',
#  'stade-reims',
#  'rc-strassburg-alsace',
#  'montpellier-hsc',
#  'fc-nantes',
#  'as-saint-etienne',
#  'stade-brest-29',
#  'fc-girondins-bordeaux',
#  'fc-metz',
#  'sco-angers',
#  'es-troyes-ac',
#  'fc-lorient',
#  'clermont-foot-63',
#  'fc-bayern-munchen',
#  'borussia-dortmund',
#  'rasenballsport-leipzig',
#  'bayer-04-leverkusen',
#  'eintracht-frankfurt',
#  'vfl-wolfsburg',
#  'borussia-monchengladbach',
#  'tsg-1899-hoffenheim',
#  'vfb-stuttgart',
#  'sc-freiburg',
#  '1-fsv-mainz-05',
#  '1-fc-koln',
#  'fc-augsburg',
#  'hertha-bsc',
#  '1-fc-union-berlin',
#  'arminia-bielefeld',
#  'vfl-bochum',
#  'spvgg-greuther-furth']

# %%
filter_table = club_read.loc[(club_read.domestic_competition_id == 'GB1') & (club_read.name.isin(team_names))].iloc[:,[0,1,2,3,-1]]

# %%
epl_table = pd.DataFrame({'name':team_names}).merge(filter_table)
epl_table
# Out:
#                         name  club_id               pretty_name  \
# 0            manchester-city      281           Manchester City
# 1               fc-liverpool       31              Fc Liverpool
# 2                 fc-chelsea      631                Fc Chelsea
# 3          manchester-united      985         Manchester United
# 4          tottenham-hotspur      148         Tottenham Hotspur
# 5                 fc-arsenal       11                Fc Arsenal
# 6             leicester-city     1003            Leicester City
# 7                aston-villa      405               Aston Villa
# 8                 fc-everton       29                Fc Everton
# 9    wolverhampton-wanderers      543   Wolverhampton Wanderers
# 10           west-ham-united      379           West Ham United
# 11              leeds-united      399              Leeds United
# 12          newcastle-united      762          Newcastle United
# 13  brighton-amp-hove-albion     1237  Brighton Amp Hove Albion
# 14            fc-southampton      180            Fc Southampton
# 15              fc-brentford     1148              Fc Brentford
# 16            crystal-palace      873            Crystal Palace
# 17              norwich-city     1123              Norwich City
# 18                fc-watford     1010                Fc Watford
# 19                fc-burnley     1132                Fc Burnley
#
# 32  attack - Centre-Forward  Right           178           54000000.0
# 33  attack - Centre-Forward  Right           178           54000000.0
# 34  attack - Centre-Forward  Right           178           54000000.0
# 35  attack - Centre-Forward  Right           178           54000000.0
# 36  attack - Centre-Forward  Right           178           54000000.0
# 37  attack - Centre-Forward  Right           178           54000000.0
# 38  attack - Centre-Forward  Right           178           54000000.0
# 39  attack - Centre-Forward  Right           178           54000000.0
#
#     highest_market_value_in_gbp  \
# 23                   54000000.0
# 24                   54000000.0
# 25                   54000000.0
# 26                   54000000.0
# 27                   54000000.0
# 28                   54000000.0
# 29                   54000000.0
# 30                   54000000.0
# 31                   54000000.0
# 32                   54000000.0
# 33                   54000000.0
# 34                   54000000.0
# 35                   54000000.0
# 36                   54000000.0
# 37                   54000000.0
# 38                   54000000.0
# 39                   54000000.0
#
#                                                   url        date  \
# 23  https://www.transfermarkt.co.uk/diogo-jota/pro...  2014-09-30
# 24  https://www.transfermarkt.co.uk/diogo-jota/pro...  2015-02-17
# 25  https://www.transfermarkt.co.uk/diogo-jota/pro...  2015-07-01
# 26  https://www.transfermarkt.co.uk/diogo-jota/pro...  2016-02-24
# 27  https://www.transfermarkt.co.uk/diogo-jota/pro...  2016-07-15
# 28  https://www.transfermarkt.co.uk/diogo-jota/pro...  2017-02-22
# 29  https://www.transfermarkt.co.uk/diogo-jota/pro...  2017-06-26
# 30  https://www.transfermarkt.co.uk/diogo-jota/pro...  2018-02-27
# 31  https://www.transfermarkt.co.uk/diogo-jota/pro...  2018-08-13
# 32  https://www.transfermarkt.co.uk/diogo-jota/pro...  2018-12-19
# 33  https://www.transfermarkt.co.uk/diogo-jota/pro...  2019-06-13
# 34  https://www.transfermarkt.co.uk/diogo-jota/pro...  2019-12-10
# 35  https://www.transfermarkt.co.uk/diogo-jota/pro...  2020-04-08
# 36  https://www.transfermarkt.co.uk/diogo-jota/pro...  2020-10-13
# 37  https://www.transfermarkt.co.uk/diogo-jota/pro...  2021-03-18
# 38  https://www.transfermarkt.co.uk/diogo-jota/pro...  2021-06-01
# 39  https://www.transfermarkt.co.uk/diogo-jota/pro...  2021-12-23
#
#     market_value
# 23         90000
# 24        225000
# 25        630000
# 26       2700000
# 27       6300000
# 28       7200000
# 29       7200000
# 30      10800000
# 31      16200000
# 32      16200000
# 33      31500000
# 34      31500000
# 35      25200000
# 36      36000000
# 37      36000000
# 38      40500000
# 39      54000000

# %%
datelist = list(past_data.date)
datelist
# Out:
# ['2014-09-30',
#  '2015-02-17',
#  '2015-07-01',
#  '2016-02-24',
#  '2016-07-15',
#  '2017-02-22',
#  '2017-06-26',
#  '2018-02-27',
#  '2018-08-13',
#  '2018-12-19',
#  '2019-06-13',
#  '2019-12-10',
#  '2020-04-08',
#  '2020-10-13',
#  '2021-03-18',
#  '2021-06-01',
#  '2021-12-23']

# %%
def endseason(date):
    return abs(sum(int(date[5:7])-i for i in [5,6,7,8,9]))

def date_extract(datelist):
    yearlist = {}
    for date in datelist:
        if not date[:4] in yearlist:
            yearlist[date[:4]] = date
        elif endseason(date) < endseason(yearlist[date[:4]]):
            yearlist[date[:4]] = date
        
    dateyear = {}
    for year in yearlist:
        dateyear[yearlist[year]] = year
    return yearlist, dateyear
            
date_extract(datelist)
# Out:
# ({'2014': '2014-09-30',
#   '2015': '2015-07-01',
#   '2016': '2016-07-15',
#   '2017': '2017-06-26',
#   '2018': '2018-08-13',
#   '2019': '2019-06-13',
#   '2020': '2020-04-08',
#   '2021': '2021-06-01'},
#  {'2014-09-30': '2014',
#   '2015-07-01': '2015',
#   '2016-07-15': '2016',
#   '2017-06-26': '2017',
#   '2018-08-13': '2018',
#   '2019-06-13': '2019',
#   '2020-04-08': '2020',
#   '2021-06-01': '2021'})

# %%
past_data = past_data.loc[past_data.date.isin(date_extract(list(past_data.date))[0].values())]
past_data.replace({"date":date_extract(list(past_data.date))[1]}).rename(columns = {"date":"year"})
# Out:
#     player_id  last_season  current_club_id        name pretty_name  \
# 23     340950         2021               31  diogo-jota  Diogo Jota
# 25     340950         2021               31  diogo-jota  Diogo Jota
# 27     340950         2021               31  diogo-jota  Diogo Jota
# 29     340950         2021               31  diogo-jota  Diogo Jota
# 31     340950         2021               31  diogo-jota  Diogo Jota
# 33     340950         2021               31  diogo-jota  Diogo Jota
# 35     340950         2021               31  diogo-jota  Diogo Jota
# 38     340950         2021               31  diogo-jota  Diogo Jota
#
#    country_of_birth country_of_citizenship date_of_birth position  \
# 23         Portugal               Portugal     12/4/1996   Attack
# 25         Portugal               Portugal     12/4/1996   Attack
# 27         Portugal               Portugal     12/4/1996   Attack
# 29         Portugal               Portugal     12/4/1996   Attack
# 31         Portugal               Portugal     12/4/1996   Attack
# 33         Portugal               Portugal     12/4/1996   Attack
# 35         Portugal               Portugal     12/4/1996   Attack
# 38         Portugal               Portugal     12/4/1996   Attack
#
#                sub_position   foot  height_in_cm  market_value_in_gbp  \
# 23  attack - Centre-Forward  Right           178           54000000.0
# 25  attack - Centre-Forward  Right           178           54000000.0
# 27  attack - Centre-Forward  Right           178           54000000.0
# 29  attack - Centre-Forward  Right           178           54000000.0
# 31  attack - Centre-Forward  Right           178           54000000.0
# 33  attack - Centre-Forward  Right           178           54000000.0
# 35  attack - Centre-Forward  Right           178           54000000.0
# 38  attack - Centre-Forward  Right           178           54000000.0
#
#     highest_market_value_in_gbp  \
# 23                   54000000.0
# 25                   54000000.0
# 27                   54000000.0
# 29                   54000000.0
# 31                   54000000.0
# 33                   54000000.0
# 35                   54000000.0
# 38                   54000000.0
#
#                                                   url  year  market_value
# 23  https://www.transfermarkt.co.uk/diogo-jota/pro...  2014         90000
# 25  https://www.transfermarkt.co.uk/diogo-jota/pro...  2015        630000
# 27  https://www.transfermarkt.co.uk/diogo-jota/pro...  2016       6300000
# 29  https://www.transfermarkt.co.uk/diogo-jota/pro...  2017       7200000
# 31  https://www.transfermarkt.co.uk/diogo-jota/pro...  2018      16200000
# 33  https://www.transfermarkt.co.uk/diogo-jota/pro...  2019      31500000
# 35  https://www.transfermarkt.co.uk/diogo-jota/pro...  2020      25200000
# 38  https://www.transfermarkt.co.uk/diogo-jota/pro...  2021      40500000
